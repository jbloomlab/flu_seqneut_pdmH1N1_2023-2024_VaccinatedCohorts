# %% [markdown]
# # Process plate counts to get ratios of variants and determine pooling and MOI
# This notebook is designed to be run using `snakemake`, and analyzes a plate of sequencing-based neutralization assays.
#
# The plots generated by this notebook are interactive, so you can mouseover points for details, use the mouse-scroll to zoom and pan, and use interactive dropdowns at the bottom of the plots.
#
# ## Setup
# Import Python modules:

# %%
import pickle
import sys

import altair as alt

import matplotlib.pyplot as plt

import numpy

import pandas as pd
from os.path import join
import os
import ruamel.yaml as yaml
import numpy as np

_ = alt.data_transformers.disable_max_rows()

# %% [markdown]
# Get the variables passed by `snakemake`:

# %%
#count_csvs = snakemake.input.count_csvs
#fate_csvs = snakemake.input.fate_csvs
#viral_library_csv = snakemake.input.viral_library_csv
#neut_standard_set_csv = snakemake.input.neut_standard_set_csv
#samples = snakemake.params.samples
#plate = "Titer_plate"

# %%
viral_library_csv = "../data/viral_libraries/H1N1_2023_library.csv"
neut_standard_set_csv = "../data/neut_standard_sets/loes2023_neut_standards.csv"
filepath_prefix = "../"
barcode_runs_df = pd.read_csv("../data/plates/plate4_MOItests_6and8hr.csv")
barcode_runs_df.drop(columns=["fastq"], inplace=True)
barcode_runs_df["sample"] = barcode_runs_df.apply(
    lambda x: "-".join(x.astype(str)), axis=1
)

samples = barcode_runs_df["well"].unique().tolist()
print(f"There are {len(samples)} barcode runs.")

file_list = os.listdir(r'../results/miscellaneous_plates/plate4_MOItests')
count_csvs = []
for f in file_list:
    location = '../results/miscellaneous_plates/plate4_MOItests/' + f
    if "_counts" in f:
        count_csvs.append(location)

# file_list_withdir
fate_csvs = []
file_list = os.listdir(r'../results/miscellaneous_plates/plate4_MOItests/')
for f in file_list:
    location = '../results/miscellaneous_plates/plate4_MOItests/' + f
    if "_fates" in f:
        fate_csvs.append(location)

samples_df = barcode_runs_df
samples_df
# Out:
# There are 56 barcode runs.
#    well             serum  dilution_factor  replicate  \
# 0    B1  MOI_100K_rep1_6h                2          1
# 1    C1  MOI_100K_rep1_6h                4          1
# 2    D1  MOI_100K_rep1_6h                8          1
# 3    E1  MOI_100K_rep1_6h               16          1
# 4    F1  MOI_100K_rep1_6h               32          1
# 5    G1  MOI_100K_rep1_6h               64          1
# 6    H1  MOI_100K_rep1_6h              128          1
# 7    B2  MOI_100K_rep2_6h                2          2
# 8    C2  MOI_100K_rep2_6h                4          2
# 9    D2  MOI_100K_rep2_6h                8          2
# 10   E2  MOI_100K_rep2_6h               16          2
# 11   F2  MOI_100K_rep2_6h               32          2
# 12   G2  MOI_100K_rep2_6h               64          2
# 13   H2  MOI_100K_rep2_6h              128          2
# 14   B4  MOI_200K_rep1_6h                2          1
# 15   C4  MOI_200K_rep1_6h                4          1
# 16   D4  MOI_200K_rep1_6h                8          1
# 17   E4  MOI_200K_rep1_6h               16          1
# 18   F4  MOI_200K_rep1_6h               32          1
# 19   G4  MOI_200K_rep1_6h               64          1
# 20   H4  MOI_200K_rep1_6h              128          1
# 21   B5  MOI_200K_rep2_6h                2          2
# 22   C5  MOI_200K_rep2_6h                4          2
# 23   D5  MOI_200K_rep2_6h                8          2
# 24   E5  MOI_200K_rep2_6h               16          2
# 25   F5  MOI_200K_rep2_6h               32          2
# 26   G5  MOI_200K_rep2_6h               64          2
# 27   H5  MOI_200K_rep2_6h              128          2
# 28   B7  MOI_100K_rep1_8h                2          1
# 29   C7  MOI_100K_rep1_8h                4          1
# 30   D7  MOI_100K_rep1_8h                8          1
# 31   E7  MOI_100K_rep1_8h               16          1
# 32   F7  MOI_100K_rep1_8h               32          1
# 33   G7  MOI_100K_rep1_8h               64          1
# 34   H7  MOI_100K_rep1_8h              128          1
# 35   B8  MOI_100K_rep2_8h                2          2
# 36   C8  MOI_100K_rep2_8h                4          2
# 37   D8  MOI_100K_rep2_8h                8          2
# 38   E8  MOI_100K_rep2_8h               16          2
# 39   F8  MOI_100K_rep2_8h               32          2
# 40   G8  MOI_100K_rep2_8h               64          2
# 41   H8  MOI_100K_rep2_8h              128          2
# 42  B10  MOI_200K_rep1_8h                2          1
# 43  C10  MOI_200K_rep1_8h                4          1
# 44  D10  MOI_200K_rep1_8h                8          1
# 45  E10  MOI_200K_rep1_8h               16          1
# 46  F10  MOI_200K_rep1_8h               32          1
# 47  G10  MOI_200K_rep1_8h               64          1
# 48  H10  MOI_200K_rep1_8h              128          1
# 49  B11  MOI_200K_rep2_8h                2          2
# 50  C11  MOI_200K_rep2_8h                4          2
# 51  D11  MOI_200K_rep2_8h                8          2
# 52  E11  MOI_200K_rep2_8h               16          2
# 53  F11  MOI_200K_rep2_8h               32          2
# 54  G11  MOI_200K_rep2_8h               64          2
# 55  H11  MOI_200K_rep2_8h              128          2
#
#                         sample
# 0      B1-MOI_100K_rep1_6h-2-1
# 1      C1-MOI_100K_rep1_6h-4-1
# 2      D1-MOI_100K_rep1_6h-8-1
# 3     E1-MOI_100K_rep1_6h-16-1
# 4     F1-MOI_100K_rep1_6h-32-1
# 5     G1-MOI_100K_rep1_6h-64-1
# 6    H1-MOI_100K_rep1_6h-128-1
# 7      B2-MOI_100K_rep2_6h-2-2
# 8      C2-MOI_100K_rep2_6h-4-2
# 9      D2-MOI_100K_rep2_6h-8-2
# 10    E2-MOI_100K_rep2_6h-16-2
# 11    F2-MOI_100K_rep2_6h-32-2
# 12    G2-MOI_100K_rep2_6h-64-2
# 13   H2-MOI_100K_rep2_6h-128-2
# 14     B4-MOI_200K_rep1_6h-2-1
# 15     C4-MOI_200K_rep1_6h-4-1
# 16     D4-MOI_200K_rep1_6h-8-1
# 17    E4-MOI_200K_rep1_6h-16-1
# 18    F4-MOI_200K_rep1_6h-32-1
# 19    G4-MOI_200K_rep1_6h-64-1
# 20   H4-MOI_200K_rep1_6h-128-1
# 21     B5-MOI_200K_rep2_6h-2-2
# 22     C5-MOI_200K_rep2_6h-4-2
# 23     D5-MOI_200K_rep2_6h-8-2
# 24    E5-MOI_200K_rep2_6h-16-2
# 25    F5-MOI_200K_rep2_6h-32-2
# 26    G5-MOI_200K_rep2_6h-64-2
# 27   H5-MOI_200K_rep2_6h-128-2
# 28     B7-MOI_100K_rep1_8h-2-1
# 29     C7-MOI_100K_rep1_8h-4-1
# 30     D7-MOI_100K_rep1_8h-8-1
# 31    E7-MOI_100K_rep1_8h-16-1
# 32    F7-MOI_100K_rep1_8h-32-1
# 33    G7-MOI_100K_rep1_8h-64-1
# 34   H7-MOI_100K_rep1_8h-128-1
# 35     B8-MOI_100K_rep2_8h-2-2
# 36     C8-MOI_100K_rep2_8h-4-2
# 37     D8-MOI_100K_rep2_8h-8-2
# 38    E8-MOI_100K_rep2_8h-16-2
# 39    F8-MOI_100K_rep2_8h-32-2
# 40    G8-MOI_100K_rep2_8h-64-2
# 41   H8-MOI_100K_rep2_8h-128-2
# 42    B10-MOI_200K_rep1_8h-2-1
# 43    C10-MOI_200K_rep1_8h-4-1
# 44    D10-MOI_200K_rep1_8h-8-1
# 45   E10-MOI_200K_rep1_8h-16-1
# 46   F10-MOI_200K_rep1_8h-32-1
# 47   G10-MOI_200K_rep1_8h-64-1
# 48  H10-MOI_200K_rep1_8h-128-1
# 49    B11-MOI_200K_rep2_8h-2-2
# 50    C11-MOI_200K_rep2_8h-4-2
# 51    D11-MOI_200K_rep2_8h-8-2
# 52   E11-MOI_200K_rep2_8h-16-2
# 53   F11-MOI_200K_rep2_8h-32-2
# 54   G11-MOI_200K_rep2_8h-64-2
# 55  H11-MOI_200K_rep2_8h-128-2

# %% [markdown]
# ## Statistics on barcode-parsing for each sample
# Make interactive chart of the "fates" of the sequencing reads parsed for each sample on the plate.
#
# If most sequencing reads are not "valid barcodes", this could potentially indicate some problem in the sequencing or barcode set you are parsing.
#
# Potential fates are:
#  - *valid barcode*: barcode that matches a known virus or neutralization standard, we hope most reads are this.
#  - *invalid barcode*: a barcode with proper flanking sequences, but does not match a known virus or neutralization standard. If you  have a lot of reads of this type, it is probably a good idea to look at the invalid barcode CSVs (in the `./results/barcode_invalid/` subdirectory created by the pipeline) to see what these invalid barcodes are.
#  - *unparseable barcode*: could not parse a barcode from this read as there was not a sequence of the correct length with the appropriate flanking sequence.
#  - *low quality barcode*: low-quality or `N` nucleotides in barcode, could indicate problem with sequencing.
#  - *failed chastity filter*: reads that failed the Illumina chastity filter, if these are reported in the FASTQ (they may not be).
#
# Also, if the number of reads per sample is very uneven, that could indicate that you did not do a good job of balancing the different samples in the Illumina sequencing.

# %%
fates = (
    pd.concat([pd.read_csv(f).assign(well=f.strip("../results/miscellaneous_plates/plate4_MOItests/").strip('_fates.csv')) for f, s in zip(fate_csvs, samples)])
    .merge(samples_df, validate="many_to_one", on="well")
    .assign(
        fate_counts=lambda x: x.groupby("fate")["count"].transform("sum"),
        sample_well=lambda x: x["serum"] + " (" + x["well"] + ")",
    )
    .query("fate_counts > 0")[  # only keep fates with at least one count
        ["fate", "count", "well", "sample_well", "dilution_factor"]
    ]
)
fates
assert len(fates) == len(fates.drop_duplicates())


sample_wells = list(fates.sort_values(["dilution_factor"])["sample_well"])


fates_chart = (
    alt.Chart(fates)
    .encode(
        alt.X("count", scale=alt.Scale(nice=False, padding=3)),
        alt.Y(
            "sample_well",
            title=None,
            sort=sample_wells,
        ),
        alt.Color("fate", sort=sorted(fates["fate"].unique(), reverse=True)),
        alt.Order("fate", sort="descending"),
        tooltip=fates.columns.tolist(),
    )
    .mark_bar(height={"band": 0.85})
    .properties(
        height=alt.Step(10),
        width=200,
        title=f"Barcode parsing for initial titering plate",
    )
    .configure_axis(grid=False)
)

fates_chart
#fates
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Read barcode counts
# Read the counts per barcode:

# %%
# get barcode counts
counts = (
    pd.concat([pd.read_csv(c).assign(well=c.strip("../results/miscellaneous_plates/plate4_MOItests/").strip('_counts.csv')) for c, s in zip(count_csvs, samples)])
    .merge(samples_df, validate="many_to_one", on="well")
    .drop(columns=["replicate"])
    .assign(sample_well=lambda x: x["sample"] + " (" + x["well"] + ")")
)

# classify barcodes as viral or neut standard
barcode_class = pd.concat(
    [
        pd.read_csv(viral_library_csv)[["barcode", "strain"]].assign(
            neut_standard=False,
        ),
        pd.read_csv(neut_standard_set_csv)[["barcode"]].assign(
            neut_standard=True,
            strain=pd.NA,
        ),
    ],
    ignore_index=True,
)

# merge counts and classification of barcodes
assert set(counts["barcode"]) == set(barcode_class["barcode"])
counts = counts.merge(barcode_class, on="barcode", validate="many_to_one")
#assert set(sample_wells) == set(counts["sample_well"])

# %% [markdown]
# Apply any manually specified data drops:

# %% [markdown]
# ## Average counts per barcode in each well

# %% [markdown]
# Plot average counts per barcode.
# If a sample has inadequate barcode counts, it may not have good enough statistics for accurate analysis, and a QC-threshold is applied:

# %%
avg_barcode_counts = (
    counts.groupby(
        ["well", "sample_well"],
        dropna=False,
        as_index=False,
    )
    .aggregate(avg_count=pd.NamedAgg("count", "mean"))
    .assign(
        fails_qc=lambda x: (
            x["avg_count"] < 500
        ),
    )
)

avg_barcode_counts_chart = (
    alt.Chart(avg_barcode_counts)
    .encode(
        alt.X(
            "avg_count",
            title="average barcode counts per well",
            scale=alt.Scale(nice=False, padding=3),
        ),
        alt.Y("sample_well", sort=sample_wells),
        alt.Color(
            "fails_qc",
            title=f"fails {'min barcode count threshold'=}",
            legend=alt.Legend(titleLimit=500),
        ),
        tooltip=[
            alt.Tooltip(c, format=".3g") if avg_barcode_counts[c].dtype == float else c
            for c in avg_barcode_counts.columns
        ],
    )
    .mark_bar(height={"band": 0.85})
    .properties(
        height=alt.Step(10),
        width=250,
        title=f"Average barcode counts per well for titering plate",
    )
    .configure_axis(grid=False)
)

display(avg_barcode_counts_chart)

# drop wells failing QC
avg_barcode_counts_per_well_drops = list(avg_barcode_counts.query("fails_qc")["well"])
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fraction of counts from neutralization standard
# Determine the fraction of counts from the neutralization standard in each sample, and make sure this fraction passess the QC threshold.

# %%
neut_standard_fracs = (
    counts.assign(
        neut_standard_count=lambda x: x["count"] * x["neut_standard"].astype(int)
    )
    .groupby(
        ["well", "sample_well"],
        dropna=False,
        as_index=False,
    )
    .aggregate(
        total_count=pd.NamedAgg("count", "sum"),
        neut_standard_count=pd.NamedAgg("neut_standard_count", "sum"),
    )
    .assign(
        neut_standard_frac=lambda x: x["neut_standard_count"] / x["total_count"],
        fails_qc=lambda x: (
            x["neut_standard_frac"] < 0.001
        ),
    )
)

neut_standard_fracs_chart = (
    alt.Chart(neut_standard_fracs)
    .encode(
        alt.X(
            "neut_standard_frac",
            title="frac counts from neutralization standard per well",
            scale=alt.Scale(nice=False, padding=3),
        ),
        alt.Y("sample_well", sort=sample_wells),
        alt.Color(
            "fails_qc",
            title=f"fails {'min_neut_standard_frac_per_well'=}",
            legend=alt.Legend(titleLimit=500),
        ),
        tooltip=[
            alt.Tooltip(c, format=".3g") if neut_standard_fracs[c].dtype == float else c
            for c in neut_standard_fracs.columns
        ],
    )
    .mark_bar(height={"band": 0.85})
    .properties(
        height=alt.Step(10),
        width=250,
        title=f"Neutralization-standard fracs per well for titering plate",
    )
    .configure_axis(grid=False)
    .configure_legend(titleLimit=1000)
)

display(neut_standard_fracs_chart)
# Out:
# alt.Chart(...)

# %%
neut_standard_fracs['dilution'] = neut_standard_fracs['sample_well'].str.split('-').str[2].astype(int)
ax1 = neut_standard_fracs.plot.scatter(x='dilution',y='neut_standard_frac',c='#444444',s=45, xlabel='dilution', ylabel="neut_standard_frac", fontsize=10,figsize=(5,5), alpha=0.4, loglog=True)
ax1.set_ylabel('fraction neut standard',fontdict={'fontsize':20})
ax1.set_xlabel('dilution',fontdict={'fontsize':20})
ax1.set_title('Determining Linear Range',fontdict={'fontsize':20})
neut_standard_fracs['set'] = neut_standard_fracs['sample_well'].str.split('-').str[1]
neut_standard_fracs['cells'] = neut_standard_fracs['set'].str.split('_').str[1]
neut_standard_fracs['time'] = neut_standard_fracs['set'].str.split('_').str[3]
neut_standard_fracs['set'] = neut_standard_fracs['cells'] +"_" + neut_standard_fracs['time']
neut_standard_fracs['colors'] = neut_standard_fracs['time']
neut_standard_fracs['colors'] = neut_standard_fracs['colors'].replace("6h","firebrick")
neut_standard_fracs['colors'] = neut_standard_fracs['colors'].replace("8h","rebeccapurple")
neut_standard_fracs['colors2'] = neut_standard_fracs['cells']
neut_standard_fracs['colors2'] = neut_standard_fracs['colors2'].replace("100K","goldenrod")
neut_standard_fracs['colors2'] = neut_standard_fracs['colors2'].replace("200K","steelblue")
neut_standard_fracs['norm'] = neut_standard_fracs['neut_standard_frac']/neut_standard_fracs['dilution']
samples = neut_standard_fracs['time'].unique().tolist()
neut_standard_fracs
for i in samples:
    ax1 = neut_standard_fracs.loc[neut_standard_fracs['time'] == i].plot.scatter(x='dilution',y='neut_standard_frac',c='colors2',s=45, xlabel='dilution', ylabel="neut_standard_frac", fontsize=10,figsize=(4,4), alpha=0.4, loglog=True)
    ax1.set_ylabel('fraction neut standard',fontdict={'fontsize':12})
    ax1.set_xlabel('dilution',fontdict={'fontsize':12})
    ax1.set_title(i,fontdict={'fontsize':20})


neut_standard_fracs
# Out:
#    well                       sample_well  total_count  neut_standard_count  \
# 0    B1      B1-MOI_100K_rep1_6h-2-1 (B1)      1492636                 7681
# 1   B10    B10-MOI_200K_rep1_8h-2-1 (B10)      1042753                 5532
# 2   B11    B11-MOI_200K_rep2_8h-2-2 (B11)       489536                 2694
# 3    B2      B2-MOI_100K_rep2_6h-2-2 (B2)      1122950                 5833
# 4    B4      B4-MOI_200K_rep1_6h-2-1 (B4)      1230160                 6719
# 5    B5      B5-MOI_200K_rep2_6h-2-2 (B5)      1418934                 8969
# 6    B7      B7-MOI_100K_rep1_8h-2-1 (B7)       882817                 3947
# 7    B8      B8-MOI_100K_rep2_8h-2-2 (B8)       875337                 3953
# 8    C1      C1-MOI_100K_rep1_6h-4-1 (C1)      1170422                 8532
# 9   C10    C10-MOI_200K_rep1_8h-4-1 (C10)      1364406                 9329
# 10  C11    C11-MOI_200K_rep2_8h-4-2 (C11)      1110584                 7511
# 11   C2      C2-MOI_100K_rep2_6h-4-2 (C2)       836061                 5107
# 12   C4      C4-MOI_200K_rep1_6h-4-1 (C4)      1398455                11502
# 13   C5      C5-MOI_200K_rep2_6h-4-2 (C5)      1368301                13016
# 14   C7      C7-MOI_100K_rep1_8h-4-1 (C7)       886444                 4798
# 15   C8      C8-MOI_100K_rep2_8h-4-2 (C8)      1240022                 7599
# 16   D1      D1-MOI_100K_rep1_6h-8-1 (D1)       936899                 9951
# 17  D10    D10-MOI_200K_rep1_8h-8-1 (D10)      1362715                11437
# 18  D11    D11-MOI_200K_rep2_8h-8-2 (D11)      1148119                10477
# 19   D2      D2-MOI_100K_rep2_6h-8-2 (D2)      1131312                 9785
# 20   D4      D4-MOI_200K_rep1_6h-8-1 (D4)      1434490                16142
# 21   D5      D5-MOI_200K_rep2_6h-8-2 (D5)      1407080                19125
# 22   D7      D7-MOI_100K_rep1_8h-8-1 (D7)       878112                 6250
# 23   D8      D8-MOI_100K_rep2_8h-8-2 (D8)      1147643                 9118
# 24   E1     E1-MOI_100K_rep1_6h-16-1 (E1)       987315                19231
# 25  E10   E10-MOI_200K_rep1_8h-16-1 (E10)      1089025                15042
# 26  E11   E11-MOI_200K_rep2_8h-16-2 (E11)      1094008                18130
# 27   E2     E2-MOI_100K_rep2_6h-16-2 (E2)      1451441                21079
# 28   E4     E4-MOI_200K_rep1_6h-16-1 (E4)      1217552                27384
# 29   E5     E5-MOI_200K_rep2_6h-16-2 (E5)      1650806                38601
# 30   E7     E7-MOI_100K_rep1_8h-16-1 (E7)       819314                 7976
# 31   E8     E8-MOI_100K_rep2_8h-16-2 (E8)      1785865                19924
# 32   F1     F1-MOI_100K_rep1_6h-32-1 (F1)      1463597                58891
# 33  F10   F10-MOI_200K_rep1_8h-32-1 (F10)      1293906                29656
# 34  F11   F11-MOI_200K_rep2_8h-32-2 (F11)      1187069                36638
# 35   F2     F2-MOI_100K_rep2_6h-32-2 (F2)       401935                14296
# 36   F4     F4-MOI_200K_rep1_6h-32-1 (F4)       670552                33881
# 37   F5     F5-MOI_200K_rep2_6h-32-2 (F5)      1456224                95931
# 38   F7     F7-MOI_100K_rep1_8h-32-1 (F7)       915830                11721
# 39   F8     F8-MOI_100K_rep2_8h-32-2 (F8)      1141929                17651
# 40   G1     G1-MOI_100K_rep1_6h-64-1 (G1)      1270492               115525
# 41  G10   G10-MOI_200K_rep1_8h-64-1 (G10)      1076969                38914
# 42  G11   G11-MOI_200K_rep2_8h-64-2 (G11)      2652676               131405
# 43   G2     G2-MOI_100K_rep2_6h-64-2 (G2)      1275874               102944
# 44   G4     G4-MOI_200K_rep1_6h-64-1 (G4)      1752089               212052
# 45   G5     G5-MOI_200K_rep2_6h-64-2 (G5)       549809                81037
# 46   G7     G7-MOI_100K_rep1_8h-64-1 (G7)       927129                25657
# 47   G8     G8-MOI_100K_rep2_8h-64-2 (G8)       405810                 9448
# 48   H1    H1-MOI_100K_rep1_6h-128-1 (H1)       805372               147371
# 49  H10  H10-MOI_200K_rep1_8h-128-1 (H10)      1525154                70038
# 50  H11  H11-MOI_200K_rep2_8h-128-2 (H11)      1267299               100083
# 51   H2    H2-MOI_100K_rep2_6h-128-2 (H2)      1398099               312823
# 52   H4    H4-MOI_200K_rep1_6h-128-1 (H4)      1875434               539467
# 53   H5    H5-MOI_200K_rep2_6h-128-2 (H5)       860364               252099
# 54   H7    H7-MOI_100K_rep1_8h-128-1 (H7)       799728                34616
# 55   H8    H8-MOI_100K_rep2_8h-128-2 (H8)       942932                46283
#
#     neut_standard_frac  fails_qc  dilution      set cells time         colors  \
# 0             0.005146     False         2  100K_6h  100K   6h      firebrick
# 1             0.005305     False         2  200K_8h  200K   8h  rebeccapurple
# 2             0.005503     False         2  200K_8h  200K   8h  rebeccapurple
# 3             0.005194     False         2  100K_6h  100K   6h      firebrick
# 4             0.005462     False         2  200K_6h  200K   6h      firebrick
# 5             0.006321     False         2  200K_6h  200K   6h      firebrick
# 6             0.004471     False         2  100K_8h  100K   8h  rebeccapurple
# 7             0.004516     False         2  100K_8h  100K   8h  rebeccapurple
# 8             0.007290     False         4  100K_6h  100K   6h      firebrick
# 9             0.006837     False         4  200K_8h  200K   8h  rebeccapurple
# 10            0.006763     False         4  200K_8h  200K   8h  rebeccapurple
# 11            0.006108     False         4  100K_6h  100K   6h      firebrick
# 12            0.008225     False         4  200K_6h  200K   6h      firebrick
# 13            0.009513     False         4  200K_6h  200K   6h      firebrick
# 14            0.005413     False         4  100K_8h  100K   8h  rebeccapurple
# 15            0.006128     False         4  100K_8h  100K   8h  rebeccapurple
# 16            0.010621     False         8  100K_6h  100K   6h      firebrick
# 17            0.008393     False         8  200K_8h  200K   8h  rebeccapurple
# 18            0.009125     False         8  200K_8h  200K   8h  rebeccapurple
# 19            0.008649     False         8  100K_6h  100K   6h      firebrick
# 20            0.011253     False         8  200K_6h  200K   6h      firebrick
# 21            0.013592     False         8  200K_6h  200K   6h      firebrick
# 22            0.007118     False         8  100K_8h  100K   8h  rebeccapurple
# 23            0.007945     False         8  100K_8h  100K   8h  rebeccapurple
# 24            0.019478     False        16  100K_6h  100K   6h      firebrick
# 25            0.013812     False        16  200K_8h  200K   8h  rebeccapurple
# 26            0.016572     False        16  200K_8h  200K   8h  rebeccapurple
# 27            0.014523     False        16  100K_6h  100K   6h      firebrick
# 28            0.022491     False        16  200K_6h  200K   6h      firebrick
# 29            0.023383     False        16  200K_6h  200K   6h      firebrick
# 30            0.009735     False        16  100K_8h  100K   8h  rebeccapurple
# 31            0.011156     False        16  100K_8h  100K   8h  rebeccapurple
# 32            0.040237     False        32  100K_6h  100K   6h      firebrick
# 33            0.022920     False        32  200K_8h  200K   8h  rebeccapurple
# 34            0.030864     False        32  200K_8h  200K   8h  rebeccapurple
# 35            0.035568     False        32  100K_6h  100K   6h      firebrick
# 36            0.050527     False        32  200K_6h  200K   6h      firebrick
# 37            0.065877     False        32  200K_6h  200K   6h      firebrick
# 38            0.012798     False        32  100K_8h  100K   8h  rebeccapurple
# 39            0.015457     False        32  100K_8h  100K   8h  rebeccapurple
# 40            0.090929     False        64  100K_6h  100K   6h      firebrick
# 41            0.036133     False        64  200K_8h  200K   8h  rebeccapurple
# 42            0.049537     False        64  200K_8h  200K   8h  rebeccapurple
# 43            0.080685     False        64  100K_6h  100K   6h      firebrick
# 44            0.121028     False        64  200K_6h  200K   6h      firebrick
# 45            0.147391     False        64  200K_6h  200K   6h      firebrick
# 46            0.027674     False        64  100K_8h  100K   8h  rebeccapurple
# 47            0.023282     False        64  100K_8h  100K   8h  rebeccapurple
# 48            0.182985     False       128  100K_6h  100K   6h      firebrick
# 49            0.045922     False       128  200K_8h  200K   8h  rebeccapurple
# 50            0.078973     False       128  200K_8h  200K   8h  rebeccapurple
# 51            0.223749     False       128  100K_6h  100K   6h      firebrick
# 52            0.287649     False       128  200K_6h  200K   6h      firebrick
# 53            0.293014     False       128  200K_6h  200K   6h      firebrick
# 54            0.043285     False       128  100K_8h  100K   8h  rebeccapurple
# 55            0.049084     False       128  100K_8h  100K   8h  rebeccapurple
#
#       colors2      norm
# 0   goldenrod  0.002573
# 1   steelblue  0.002653
# 2   steelblue  0.002752
# 3   goldenrod  0.002597
# 4   steelblue  0.002731
# 5   steelblue  0.003160
# 6   goldenrod  0.002235
# 7   goldenrod  0.002258
# 8   goldenrod  0.001822
# 9   steelblue  0.001709
# 10  steelblue  0.001691
# 11  goldenrod  0.001527
# 12  steelblue  0.002056
# 13  steelblue  0.002378
# 14  goldenrod  0.001353
# 15  goldenrod  0.001532
# 16  goldenrod  0.001328
# 17  steelblue  0.001049
# 18  steelblue  0.001141
# 19  goldenrod  0.001081
# 20  steelblue  0.001407
# 21  steelblue  0.001699
# 22  goldenrod  0.000890
# 23  goldenrod  0.000993
# 24  goldenrod  0.001217
# 25  steelblue  0.000863
# 26  steelblue  0.001036
# 27  goldenrod  0.000908
# 28  steelblue  0.001406
# 29  steelblue  0.001461
# 30  goldenrod  0.000608
# 31  goldenrod  0.000697
# 32  goldenrod  0.001257
# 33  steelblue  0.000716
# 34  steelblue  0.000965
# 35  goldenrod  0.001111
# 36  steelblue  0.001579
# 37  steelblue  0.002059
# 38  goldenrod  0.000400
# 39  goldenrod  0.000483
# 40  goldenrod  0.001421
# 41  steelblue  0.000565
# 42  steelblue  0.000774
# 43  goldenrod  0.001261
# 44  steelblue  0.001891
# 45  steelblue  0.002303
# 46  goldenrod  0.000432
# 47  goldenrod  0.000364
# 48  goldenrod  0.001430
# 49  steelblue  0.000359
# 50  steelblue  0.000617
# 51  goldenrod  0.001748
# 52  steelblue  0.002247
# 53  steelblue  0.002289
# 54  goldenrod  0.000338
# 55  goldenrod  0.000383

# %% [markdown]
# ## Testing spike in of new viruses

# %%
viral_library_csv = "../data/viral_libraries/H1N1_2023_library.csv"
neut_standard_set_csv = "../data/neut_standard_sets/loes2023_neut_standards.csv"
filepath_prefix = "../"
barcode_runs_df = pd.read_csv("../data/plates/plate4_testrescues.csv")
barcode_runs_df.drop(columns=["fastq"], inplace=True)
barcode_runs_df["sample"] = barcode_runs_df.apply(
    lambda x: "-".join(x.astype(str)), axis=1
)

samples = barcode_runs_df["well"].unique().tolist()
print(f"There are {len(samples)} barcode runs.")

file_list = os.listdir(r'../results/miscellaneous_plates/plate4_testrescues')
count_csvs = []
for f in file_list:
    location = '../results/miscellaneous_plates/plate4_testrescues/' + f
    if "_counts" in f:
        count_csvs.append(location)

# file_list_withdir
fate_csvs = []
file_list = os.listdir(r'../results/miscellaneous_plates/plate4_testrescues/')
for f in file_list:
    location = '../results/miscellaneous_plates/plate4_testrescues/' + f
    if "_fates" in f:
        fate_csvs.append(location)

samples_df = barcode_runs_df
samples_df
# Out:
# There are 4 barcode runs.
#   well   serum  dilution_factor  replicate         sample
# 0   A3  MI23_1                1          1  A3-MI23_1-1-1
# 1   B3  MI23_2                1          1  B3-MI23_2-1-1
# 2   C3  MI23_3                1          1  C3-MI23_3-1-1
# 3   D3  VI22_1                1          1  D3-VI22_1-1-1

# %%
fates = (
    pd.concat([pd.read_csv(f).assign(well=f.strip("../results/miscellaneous_plates/plate4_testrescues/").strip('_fates.csv')) for f, s in zip(fate_csvs, samples)])
    .merge(samples_df, validate="many_to_one", on="well")
    .assign(
        fate_counts=lambda x: x.groupby("fate")["count"].transform("sum"),
        sample_well=lambda x: x["serum"] + " (" + x["well"] + ")",
    )
    .query("fate_counts > 0")[  # only keep fates with at least one count
        ["fate", "count", "well", "sample_well", "dilution_factor"]
    ]
)
fates
assert len(fates) == len(fates.drop_duplicates())


sample_wells = list(fates.sort_values(["dilution_factor"])["sample_well"])


fates_chart = (
    alt.Chart(fates)
    .encode(
        alt.X("count", scale=alt.Scale(nice=False, padding=3)),
        alt.Y(
            "sample_well",
            title=None,
            sort=sample_wells,
        ),
        alt.Color("fate", sort=sorted(fates["fate"].unique(), reverse=True)),
        alt.Order("fate", sort="descending"),
        tooltip=fates.columns.tolist(),
    )
    .mark_bar(height={"band": 0.85})
    .properties(
        height=alt.Step(10),
        width=200,
        title=f"Barcode parsing for initial titering plate",
    )
    .configure_axis(grid=False)
)

fates_chart
#fates
# Out:
# alt.Chart(...)

# %%
# get barcode counts
counts = (
    pd.concat([pd.read_csv(c).assign(well=c.strip("../results/miscellaneous_plates/plate4_testrescues/").strip('_counts.csv')) for c, s in zip(count_csvs, samples)])
    .merge(samples_df, validate="many_to_one", on="well")
    .drop(columns=["replicate"])
    .assign(sample_well=lambda x: x["sample"] + " (" + x["well"] + ")")
)

# classify barcodes as viral or neut standard
barcode_class = pd.concat(
    [
        pd.read_csv(viral_library_csv)[["barcode", "strain"]].assign(
            neut_standard=False,
        ),
        pd.read_csv(neut_standard_set_csv)[["barcode"]].assign(
            neut_standard=True,
            strain=pd.NA,
        ),
    ],
    ignore_index=True,
)

# merge counts and classification of barcodes
assert set(counts["barcode"]) == set(barcode_class["barcode"])
counts = counts.merge(barcode_class, on="barcode", validate="many_to_one")
counts
# Out:
#               barcode  count well   serum  dilution_factor         sample  \
# 0    CAAGGAAACCGGTTGA  10798   B3  MI23_2                1  B3-MI23_2-1-1
# 1    AGCAGTAAATAAAATC   6108   B3  MI23_2                1  B3-MI23_2-1-1
# 2    AAAATCATTCGACTCT   2775   B3  MI23_2                1  B3-MI23_2-1-1
# 3    CTTTAAATTATAGTCT      1   B3  MI23_2                1  B3-MI23_2-1-1
# 4    AAAAAATTTATGACAA      0   B3  MI23_2                1  B3-MI23_2-1-1
# ..                ...    ...  ...     ...              ...            ...
# 819  TTGAAAGCCACAACAC      0   C3  MI23_3                1  C3-MI23_3-1-1
# 820  TTGGGCACTAAATTAA      0   C3  MI23_3                1  C3-MI23_3-1-1
# 821  TTGGGGATTGCCCAAA      0   C3  MI23_3                1  C3-MI23_3-1-1
# 822  TTTGCTCGCAAAACCA      0   C3  MI23_3                1  C3-MI23_3-1-1
# 823  TTTTAGATAAACTTAG      0   C3  MI23_3                1  C3-MI23_3-1-1
#
#             sample_well                            strain  neut_standard
# 0    B3-MI23_2-1-1 (B3)  A/Oregon/Flu-OHSU-241140095/2023          False
# 1    B3-MI23_2-1-1 (B3)  A/Oregon/Flu-OHSU-241140095/2023          False
# 2    B3-MI23_2-1-1 (B3)  A/Oregon/Flu-OHSU-241140095/2023          False
# 3    B3-MI23_2-1-1 (B3)                               NaN           True
# 4    B3-MI23_2-1-1 (B3)                               NaN           True
# ..                  ...                               ...            ...
# 819  C3-MI23_3-1-1 (C3)            A/Pennsylvania/51/2023          False
# 820  C3-MI23_3-1-1 (C3)                A/Brisbane/02/2018          False
# 821  C3-MI23_3-1-1 (C3)              A/Washington/32/2023          False
# 822  C3-MI23_3-1-1 (C3)                A/Norway/8030/2023          False
# 823  C3-MI23_3-1-1 (C3)              A/Victoria/1389/2023          False
#
# [824 rows x 9 columns]

# %%
counts_balancedbarcode = counts.groupby(['sample','strain','dilution_factor','serum','well','barcode']).sum()
counts_balancedbarcode = counts_balancedbarcode.reset_index().drop(columns = ['neut_standard'])

# %%
#First calculate the total counts per barcode in each well
sumperwell = counts_balancedbarcode.groupby(['sample','sample_well','dilution_factor','serum','well']).sum().drop(columns=['strain','barcode'])
sumperwell = sumperwell.reset_index()
sumperwell
# Out:
#           sample         sample_well  dilution_factor   serum well  count
# 0  A3-MI23_1-1-1  A3-MI23_1-1-1 (A3)                1  MI23_1   A3  16813
# 1  B3-MI23_2-1-1  B3-MI23_2-1-1 (B3)                1  MI23_2   B3  19681
# 2  C3-MI23_3-1-1  C3-MI23_3-1-1 (C3)                1  MI23_3   C3  24165
# 3  D3-VI22_1-1-1  D3-VI22_1-1-1 (D3)                1  VI22_1   D3  21628

# %%
#Then calculate the sum of barcodes corresponding to barcoded variants per well and calculate the fraction of counts that each barcode represents of barcode counts per well
sumperwell = sumperwell.rename(columns={'count':'counts_perwell'})
counts_balancedbarcode = counts_balancedbarcode.merge(sumperwell, on=['sample','sample_well','dilution_factor','serum','well'])
counts_balancedbarcode['fraction_barcode'] = counts_balancedbarcode['count'] /counts_balancedbarcode['counts_perwell'] 
counts_balancedbarcode = counts_balancedbarcode.loc[counts_balancedbarcode['count'] > 1]

# %%
counts_balancedbarcode
# Out:
#             sample                            strain  dilution_factor   serum  \
# 95   A3-MI23_1-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_1
# 96   A3-MI23_1-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_1
# 97   A3-MI23_1-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_1
# 292  B3-MI23_2-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_2
# 293  B3-MI23_2-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_2
# 294  B3-MI23_2-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_2
# 489  C3-MI23_3-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_3
# 490  C3-MI23_3-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_3
# 491  C3-MI23_3-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_3
# 776  D3-VI22_1-1-1       A/Victoria/4897/2022_IVR238                1  VI22_1
# 777  D3-VI22_1-1-1       A/Victoria/4897/2022_IVR238                1  VI22_1
# 778  D3-VI22_1-1-1       A/Victoria/4897/2022_IVR238                1  VI22_1
#
#     well           barcode  count         sample_well  counts_perwell  \
# 95    A3  AAAATCATTCGACTCT   2470  A3-MI23_1-1-1 (A3)           16813
# 96    A3  AGCAGTAAATAAAATC   5279  A3-MI23_1-1-1 (A3)           16813
# 97    A3  CAAGGAAACCGGTTGA   9064  A3-MI23_1-1-1 (A3)           16813
# 292   B3  AAAATCATTCGACTCT   2775  B3-MI23_2-1-1 (B3)           19681
# 293   B3  AGCAGTAAATAAAATC   6108  B3-MI23_2-1-1 (B3)           19681
# 294   B3  CAAGGAAACCGGTTGA  10798  B3-MI23_2-1-1 (B3)           19681
# 489   C3  AAAATCATTCGACTCT   3563  C3-MI23_3-1-1 (C3)           24165
# 490   C3  AGCAGTAAATAAAATC   7234  C3-MI23_3-1-1 (C3)           24165
# 491   C3  CAAGGAAACCGGTTGA  13365  C3-MI23_3-1-1 (C3)           24165
# 776   D3  AAGTTAAGAGAAAGTT  15783  D3-VI22_1-1-1 (D3)           21628
# 777   D3  AATCCGAAATTTATTC    792  D3-VI22_1-1-1 (D3)           21628
# 778   D3  AGAGCTAAAAAGAGGA   5052  D3-VI22_1-1-1 (D3)           21628
#
#      fraction_barcode
# 95           0.146910
# 96           0.313983
# 97           0.539107
# 292          0.140999
# 293          0.310350
# 294          0.548651
# 489          0.147445
# 490          0.299359
# 491          0.553073
# 776          0.729748
# 777          0.036619
# 778          0.233586

# %%
#Now we select a couple wells where we think the vRNA counts should correspond to linearly to titers based on prior experiments amd calculate the sum of all barcodes for each strain and determine the fraction of counts that is each strain
subset_of_wells = counts_balancedbarcode.loc[counts_balancedbarcode['sample'].str.contains('A3|B3|C3|D3')] #Take wells where fraction neut-standard is reasonable
sum_barcodes_bystrain = subset_of_wells.groupby(['strain','well'])['fraction_barcode'].sum().to_frame().rename(columns = {'fraction_barcode': 'fraction_strain_perwell'}).reset_index()

# %%
mean_df = sum_barcodes_bystrain.groupby(['strain'])['fraction_strain_perwell'].mean().to_frame().rename(columns = {'fraction_strain_perwell': 'mean_fraction_strains_subsetwells'}).reset_index()
mean_df = sum_barcodes_bystrain.merge(mean_df, on = 'strain', how = 'left')

# %%
mean_single_well = subset_of_wells.merge(mean_df, on = ['strain','well'], how = 'left')

# calcualte ratios to add
num_strains = 64
mean_single_well['ratio_to_add'] = (1/num_strains)/mean_single_well['fraction_strain_perwell']
mean_single_well['mean_ratio_to_add'] = (1/num_strains)/mean_single_well['mean_fraction_strains_subsetwells']

mean_single_well['est_tcid50'] = (mean_single_well['mean_fraction_strains_subsetwells']*17433)*64

mean_single_well
# Out:
#            sample                            strain  dilution_factor   serum  \
# 0   A3-MI23_1-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_1
# 1   A3-MI23_1-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_1
# 2   A3-MI23_1-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_1
# 3   B3-MI23_2-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_2
# 4   B3-MI23_2-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_2
# 5   B3-MI23_2-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_2
# 6   C3-MI23_3-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_3
# 7   C3-MI23_3-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_3
# 8   C3-MI23_3-1-1  A/Oregon/Flu-OHSU-241140095/2023                1  MI23_3
# 9   D3-VI22_1-1-1       A/Victoria/4897/2022_IVR238                1  VI22_1
# 10  D3-VI22_1-1-1       A/Victoria/4897/2022_IVR238                1  VI22_1
# 11  D3-VI22_1-1-1       A/Victoria/4897/2022_IVR238                1  VI22_1
#
#    well           barcode  count         sample_well  counts_perwell  \
# 0    A3  AAAATCATTCGACTCT   2470  A3-MI23_1-1-1 (A3)           16813
# 1    A3  AGCAGTAAATAAAATC   5279  A3-MI23_1-1-1 (A3)           16813
# 2    A3  CAAGGAAACCGGTTGA   9064  A3-MI23_1-1-1 (A3)           16813
# 3    B3  AAAATCATTCGACTCT   2775  B3-MI23_2-1-1 (B3)           19681
# 4    B3  AGCAGTAAATAAAATC   6108  B3-MI23_2-1-1 (B3)           19681
# 5    B3  CAAGGAAACCGGTTGA  10798  B3-MI23_2-1-1 (B3)           19681
# 6    C3  AAAATCATTCGACTCT   3563  C3-MI23_3-1-1 (C3)           24165
# 7    C3  AGCAGTAAATAAAATC   7234  C3-MI23_3-1-1 (C3)           24165
# 8    C3  CAAGGAAACCGGTTGA  13365  C3-MI23_3-1-1 (C3)           24165
# 9    D3  AAGTTAAGAGAAAGTT  15783  D3-VI22_1-1-1 (D3)           21628
# 10   D3  AATCCGAAATTTATTC    792  D3-VI22_1-1-1 (D3)           21628
# 11   D3  AGAGCTAAAAAGAGGA   5052  D3-VI22_1-1-1 (D3)           21628
#
#     fraction_barcode  fraction_strain_perwell  \
# 0           0.146910                 1.000000
# 1           0.313983                 1.000000
# 2           0.539107                 1.000000
# 3           0.140999                 1.000000
# 4           0.310350                 1.000000
# 5           0.548651                 1.000000
# 6           0.147445                 0.999876
# 7           0.299359                 0.999876
# 8           0.553073                 0.999876
# 9           0.729748                 0.999954
# 10          0.036619                 0.999954
# 11          0.233586                 0.999954
#
#     mean_fraction_strains_subsetwells  ratio_to_add  mean_ratio_to_add  \
# 0                            0.999959      0.015625           0.015626
# 1                            0.999959      0.015625           0.015626
# 2                            0.999959      0.015625           0.015626
# 3                            0.999959      0.015625           0.015626
# 4                            0.999959      0.015625           0.015626
# 5                            0.999959      0.015625           0.015626
# 6                            0.999959      0.015627           0.015626
# 7                            0.999959      0.015627           0.015626
# 8                            0.999959      0.015627           0.015626
# 9                            0.999954      0.015626           0.015626
# 10                           0.999954      0.015626           0.015626
# 11                           0.999954      0.015626           0.015626
#
#       est_tcid50
# 0   1.115666e+06
# 1   1.115666e+06
# 2   1.115666e+06
# 3   1.115666e+06
# 4   1.115666e+06
# 5   1.115666e+06
# 6   1.115666e+06
# 7   1.115666e+06
# 8   1.115666e+06
# 9   1.115660e+06
# 10  1.115660e+06
# 11  1.115660e+06

# %%
assess_barcodebalancing = mean_single_well.loc[mean_single_well['well'].str.contains('A3|B3|C3|D3')][['strain','barcode','fraction_barcode','count','counts_perwell','well']]
assess_barcodebalancing_bystrain = assess_barcodebalancing.groupby(['strain'])['count'].sum().to_frame().rename(columns = {'count': 'count_perstrain_perwell'}).reset_index()
assess_barcodebalancing_bystrain
assess_barcodebalancing = assess_barcodebalancing.merge(assess_barcodebalancing_bystrain, on="strain")
assess_barcodebalancing['fraction_of_strain_barcode'] = assess_barcodebalancing['count']/assess_barcodebalancing['count_perstrain_perwell']
assess_barcodebalancing
# Out:
#                               strain           barcode  fraction_barcode  \
# 0   A/Oregon/Flu-OHSU-241140095/2023  AAAATCATTCGACTCT          0.146910
# 1   A/Oregon/Flu-OHSU-241140095/2023  AGCAGTAAATAAAATC          0.313983
# 2   A/Oregon/Flu-OHSU-241140095/2023  CAAGGAAACCGGTTGA          0.539107
# 3   A/Oregon/Flu-OHSU-241140095/2023  AAAATCATTCGACTCT          0.140999
# 4   A/Oregon/Flu-OHSU-241140095/2023  AGCAGTAAATAAAATC          0.310350
# 5   A/Oregon/Flu-OHSU-241140095/2023  CAAGGAAACCGGTTGA          0.548651
# 6   A/Oregon/Flu-OHSU-241140095/2023  AAAATCATTCGACTCT          0.147445
# 7   A/Oregon/Flu-OHSU-241140095/2023  AGCAGTAAATAAAATC          0.299359
# 8   A/Oregon/Flu-OHSU-241140095/2023  CAAGGAAACCGGTTGA          0.553073
# 9        A/Victoria/4897/2022_IVR238  AAGTTAAGAGAAAGTT          0.729748
# 10       A/Victoria/4897/2022_IVR238  AATCCGAAATTTATTC          0.036619
# 11       A/Victoria/4897/2022_IVR238  AGAGCTAAAAAGAGGA          0.233586
#
#     count  counts_perwell well  count_perstrain_perwell  \
# 0    2470           16813   A3                    60656
# 1    5279           16813   A3                    60656
# 2    9064           16813   A3                    60656
# 3    2775           19681   B3                    60656
# 4    6108           19681   B3                    60656
# 5   10798           19681   B3                    60656
# 6    3563           24165   C3                    60656
# 7    7234           24165   C3                    60656
# 8   13365           24165   C3                    60656
# 9   15783           21628   D3                    21627
# 10    792           21628   D3                    21627
# 11   5052           21628   D3                    21627
#
#     fraction_of_strain_barcode
# 0                     0.040721
# 1                     0.087032
# 2                     0.149433
# 3                     0.045750
# 4                     0.100699
# 5                     0.178020
# 6                     0.058741
# 7                     0.119263
# 8                     0.220341
# 9                     0.729782
# 10                    0.036621
# 11                    0.233597

# %%
barcode_balance_chart = (
    alt.Chart(assess_barcodebalancing)
    .encode(
        alt.X("fraction_barcode", scale=alt.Scale(nice=False, padding=3)),
        alt.Y(
            "well",
            title=None,
            sort=sample_wells,
        ),
        alt.Color("barcode", sort=sorted(assess_barcodebalancing["strain"].unique())).scale(range = ['steelblue', 'goldenrod','firebrick']),
    )
    .mark_bar(height={"band": 0.75})
    .properties(
        height=alt.Step(36),
        width=450,
    )
    .configure_axis(grid=False,labelFontSize=18,titleFontSize=18,labelLimit=300)
)

barcode_balance_chart
# Out:
# alt.Chart(...)

# %%
## Testing volume of new viruses that we should add

# %%
barcode_runs_df = pd.read_csv("../data/plates/plate4_5J8_16hr.csv")
barcode_runs_df.drop(columns=["fastq"], inplace=True)
barcode_runs_df["sample"] = barcode_runs_df.apply(
    lambda x: "-".join(x.astype(str)), axis=1
)

samples = barcode_runs_df["well"].unique().tolist()
print(f"There are {len(samples)} barcode runs.")

file_list = os.listdir(r'../results/miscellaneous_plates/plate4_5J8_16hr')
count_csvs = []
for f in file_list:
    location = '../results/miscellaneous_plates/plate4_5J8_16hr/' + f
    if "_counts" in f:
        count_csvs.append(location)

# file_list_withdir
fate_csvs = []
file_list = os.listdir(r'../results/miscellaneous_plates/plate4_5J8_16hr/')
for f in file_list:
    location = '../results/miscellaneous_plates/plate4_5J8_16hr/' + f
    if "_fates" in f:
        fate_csvs.append(location)

samples_df = barcode_runs_df
samples_df
# Out:
# There are 16 barcode runs.
#    well           serum  dilution_factor  replicate                   sample
# 0    A1            none                1          1              A1-none-1-1
# 1    B1            none                1          2              B1-none-1-2
# 2    C1            none                1          3              C1-none-1-3
# 3    D1            none                1          4              D1-none-1-4
# 4    E1            none                1          5              E1-none-1-5
# 5    F1            none                1          6              F1-none-1-6
# 6    G1            none                1          7              G1-none-1-7
# 7    H1            none                1          8              H1-none-1-8
# 8    A2  5J8_newviruses                1          1    A2-5J8_newviruses-1-1
# 9    B2  5J8_newviruses                2          1    B2-5J8_newviruses-2-1
# 10   C2  5J8_newviruses                4          1    C2-5J8_newviruses-4-1
# 11   D2  5J8_newviruses                8          1    D2-5J8_newviruses-8-1
# 12   E2  5J8_newviruses               16          1   E2-5J8_newviruses-16-1
# 13   F2  5J8_newviruses               32          1   F2-5J8_newviruses-32-1
# 14   G2  5J8_newviruses               64          1   G2-5J8_newviruses-64-1
# 15   H2  5J8_newviruses              128          1  H2-5J8_newviruses-128-1

# %%
samples_df['sample'] = 'plate4_5J8_none-' + samples_df['replicate'].astype(str) + "_1"
samples_df = samples_df.loc[samples_df['serum'].str.contains('none')]
samples_df
# Out:
#   well serum  dilution_factor  replicate               sample
# 0   A1  none                1          1  plate4_5J8_none-1_1
# 1   B1  none                1          2  plate4_5J8_none-2_1
# 2   C1  none                1          3  plate4_5J8_none-3_1
# 3   D1  none                1          4  plate4_5J8_none-4_1
# 4   E1  none                1          5  plate4_5J8_none-5_1
# 5   F1  none                1          6  plate4_5J8_none-6_1
# 6   G1  none                1          7  plate4_5J8_none-7_1
# 7   H1  none                1          8  plate4_5J8_none-8_1

# %%
count_csvs
# Out:
# ['../results/miscellaneous_plates/plate4_5J8_16hr/H2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/D1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/B2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/E1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/B1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/C1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/C2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/F2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/A1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/F1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/E2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/G1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/G2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/H1_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/D2_counts.csv',
#  '../results/miscellaneous_plates/plate4_5J8_16hr/A2_counts.csv']

# %%
# get barcode counts
counts = (
    pd.concat([pd.read_csv(c).assign(well=c.strip("../results/miscellaneous_plates/plate4_5J8_16hr/").strip('_counts.csv')) for c, s in zip(count_csvs, samples)])
    .merge(samples_df, validate="many_to_one", on="well")
    .drop(columns=["replicate"])
    .assign(sample_well=lambda x: x["sample"] + " (" + x["well"] + ")")
)

# classify barcodes as viral or neut standard
barcode_class = pd.concat(
    [
        pd.read_csv(viral_library_csv)[["barcode", "strain"]].assign(
            neut_standard=False,
        ),
        pd.read_csv(neut_standard_set_csv)[["barcode"]].assign(
            neut_standard=True,
            strain=pd.NA,
        ),
    ],
    ignore_index=True,
)

# merge counts and classification of barcodes
assert set(counts["barcode"]) == set(barcode_class["barcode"])
counts = counts.merge(barcode_class, on="barcode", validate="many_to_one")
#assert set(sample_wells) == set(counts["sample_well"])

# %%
counts_balancedbarcode = counts.groupby(['sample','strain','dilution_factor','serum','well','barcode']).sum()
counts_balancedbarcode = counts_balancedbarcode.reset_index().drop(columns = ['neut_standard'])
counts_balancedbarcode
# Out:
#                    sample                strain  dilution_factor serum well  \
# 0     plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 1     plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 2     plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 3     plate4_5J8_none-1_1  A/Argentina/824/2023                1  none   A1
# 4     plate4_5J8_none-1_1  A/Argentina/824/2023                1  none   A1
# ...                   ...                   ...              ...   ...  ...
# 1571  plate4_5J8_none-8_1  A/Wisconsin/588/2019                1  none   H1
# 1572  plate4_5J8_none-8_1  A/Wisconsin/588/2019                1  none   H1
# 1573  plate4_5J8_none-8_1   A/Wisconsin/67/2022                1  none   H1
# 1574  plate4_5J8_none-8_1   A/Wisconsin/67/2022                1  none   H1
# 1575  plate4_5J8_none-8_1   A/Wisconsin/67/2022                1  none   H1
#
#                barcode  count               sample_well
# 0     ATATCAAGACTAGATG   9401  plate4_5J8_none-1_1 (A1)
# 1     CCGTTCTAAAACGCTA   3322  plate4_5J8_none-1_1 (A1)
# 2     CGGCAGGATATTGCAG  10082  plate4_5J8_none-1_1 (A1)
# 3     ACAAATAGTTTATAGA   7697  plate4_5J8_none-1_1 (A1)
# 4     CCACATAGGCGTTTTT    347  plate4_5J8_none-1_1 (A1)
# ...                ...    ...                       ...
# 1571  GAAGAAACTATAACCA  18112  plate4_5J8_none-8_1 (H1)
# 1572  TATATTAGTAACATAA   4489  plate4_5J8_none-8_1 (H1)
# 1573  AAAGCTCTTTTCGTTC  11213  plate4_5J8_none-8_1 (H1)
# 1574  AGGAAAGAAACTGGAG   3102  plate4_5J8_none-8_1 (H1)
# 1575  CTGAACTTGTCGATAT   1655  plate4_5J8_none-8_1 (H1)
#
# [1576 rows x 8 columns]

# %%
#First calculate the total counts per barcode in each well
sumperwell = counts_balancedbarcode.groupby(['sample','sample_well','dilution_factor','serum','well']).sum().drop(columns=['strain','barcode'])
sumperwell = sumperwell.reset_index()
sumperwell
# Out:
#                 sample               sample_well  dilution_factor serum well  \
# 0  plate4_5J8_none-1_1  plate4_5J8_none-1_1 (A1)                1  none   A1
# 1  plate4_5J8_none-2_1  plate4_5J8_none-2_1 (B1)                1  none   B1
# 2  plate4_5J8_none-3_1  plate4_5J8_none-3_1 (C1)                1  none   C1
# 3  plate4_5J8_none-4_1  plate4_5J8_none-4_1 (D1)                1  none   D1
# 4  plate4_5J8_none-5_1  plate4_5J8_none-5_1 (E1)                1  none   E1
# 5  plate4_5J8_none-6_1  plate4_5J8_none-6_1 (F1)                1  none   F1
# 6  plate4_5J8_none-7_1  plate4_5J8_none-7_1 (G1)                1  none   G1
# 7  plate4_5J8_none-8_1  plate4_5J8_none-8_1 (H1)                1  none   H1
#
#      count
# 0  1196049
# 1   900892
# 2   986264
# 3   934059
# 4  1081282
# 5        0
# 6  1038309
# 7   929805

# %%
#Then calculate the sum of barcodes corresponding to barcoded variants per well and calculate the fraction of counts that each barcode represents of barcode counts per well
sumperwell = sumperwell.rename(columns={'count':'counts_perwell'})
counts_balancedbarcode = counts_balancedbarcode.merge(sumperwell, on=['sample','sample_well','dilution_factor','serum','well'])
counts_balancedbarcode['fraction_barcode'] = counts_balancedbarcode['count'] /counts_balancedbarcode['counts_perwell'] 
counts_balancedbarcode
# Out:
#                    sample                strain  dilution_factor serum well  \
# 0     plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 1     plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 2     plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 3     plate4_5J8_none-1_1  A/Argentina/824/2023                1  none   A1
# 4     plate4_5J8_none-1_1  A/Argentina/824/2023                1  none   A1
# ...                   ...                   ...              ...   ...  ...
# 1571  plate4_5J8_none-8_1  A/Wisconsin/588/2019                1  none   H1
# 1572  plate4_5J8_none-8_1  A/Wisconsin/588/2019                1  none   H1
# 1573  plate4_5J8_none-8_1   A/Wisconsin/67/2022                1  none   H1
# 1574  plate4_5J8_none-8_1   A/Wisconsin/67/2022                1  none   H1
# 1575  plate4_5J8_none-8_1   A/Wisconsin/67/2022                1  none   H1
#
#                barcode  count               sample_well  counts_perwell  \
# 0     ATATCAAGACTAGATG   9401  plate4_5J8_none-1_1 (A1)         1196049
# 1     CCGTTCTAAAACGCTA   3322  plate4_5J8_none-1_1 (A1)         1196049
# 2     CGGCAGGATATTGCAG  10082  plate4_5J8_none-1_1 (A1)         1196049
# 3     ACAAATAGTTTATAGA   7697  plate4_5J8_none-1_1 (A1)         1196049
# 4     CCACATAGGCGTTTTT    347  plate4_5J8_none-1_1 (A1)         1196049
# ...                ...    ...                       ...             ...
# 1571  GAAGAAACTATAACCA  18112  plate4_5J8_none-8_1 (H1)          929805
# 1572  TATATTAGTAACATAA   4489  plate4_5J8_none-8_1 (H1)          929805
# 1573  AAAGCTCTTTTCGTTC  11213  plate4_5J8_none-8_1 (H1)          929805
# 1574  AGGAAAGAAACTGGAG   3102  plate4_5J8_none-8_1 (H1)          929805
# 1575  CTGAACTTGTCGATAT   1655  plate4_5J8_none-8_1 (H1)          929805
#
#       fraction_barcode
# 0             0.007860
# 1             0.002777
# 2             0.008429
# 3             0.006435
# 4             0.000290
# ...                ...
# 1571          0.019479
# 1572          0.004828
# 1573          0.012060
# 1574          0.003336
# 1575          0.001780
#
# [1576 rows x 10 columns]

# %%
#Now we select a couple wells where we think the vRNA counts should correspond to linearly to titers based on prior experiments amd calculate the sum of all barcodes for each strain and determine the fraction of counts that is each strain
subset_of_wells = counts_balancedbarcode.loc[counts_balancedbarcode['well'].str.contains('A1|B1|C1')] #Take wells where fraction neut-standard is reasonable
sum_barcodes_bystrain = subset_of_wells.groupby(['strain','well'])['fraction_barcode'].sum().to_frame().rename(columns = {'fraction_barcode': 'fraction_strain_perwell'}).reset_index()
sum_barcodes_bystrain
# Out:
#                    strain well  fraction_strain_perwell
# 0    A/Argentina/677/2023   A1                 0.019067
# 1    A/Argentina/677/2023   B1                 0.022076
# 2    A/Argentina/677/2023   C1                 0.019121
# 3    A/Argentina/824/2023   A1                 0.012108
# 4    A/Argentina/824/2023   B1                 0.010586
# ..                    ...  ...                      ...
# 193  A/Wisconsin/588/2019   B1                 0.025585
# 194  A/Wisconsin/588/2019   C1                 0.023242
# 195   A/Wisconsin/67/2022   A1                 0.018151
# 196   A/Wisconsin/67/2022   B1                 0.019496
# 197   A/Wisconsin/67/2022   C1                 0.017720
#
# [198 rows x 3 columns]

# %%
mean_df = sum_barcodes_bystrain.groupby(['strain'])['fraction_strain_perwell'].mean().to_frame().rename(columns = {'fraction_strain_perwell': 'mean_fraction_strains_subsetwells'}).reset_index()
mean_df = sum_barcodes_bystrain.merge(mean_df, on = 'strain', how = 'left')

# %%
mean_single_well = subset_of_wells.merge(mean_df, on = ['strain','well'], how = 'left')

# calcualte ratios to add
num_strains = 67
mean_single_well['ratio_to_add'] = (1/num_strains)/mean_single_well['fraction_strain_perwell']
mean_single_well['mean_ratio_to_add'] = (1/num_strains)/mean_single_well['mean_fraction_strains_subsetwells']

#mean_single_well['est_tcid50'] = (mean_single_well['mean_fraction_strains_subsetwells']*17433)*64

mean_single_well
# Out:
#                   sample                strain  dilution_factor serum well  \
# 0    plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 1    plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 2    plate4_5J8_none-1_1  A/Argentina/677/2023                1  none   A1
# 3    plate4_5J8_none-1_1  A/Argentina/824/2023                1  none   A1
# 4    plate4_5J8_none-1_1  A/Argentina/824/2023                1  none   A1
# ..                   ...                   ...              ...   ...  ...
# 586  plate4_5J8_none-3_1  A/Wisconsin/588/2019                1  none   C1
# 587  plate4_5J8_none-3_1  A/Wisconsin/588/2019                1  none   C1
# 588  plate4_5J8_none-3_1   A/Wisconsin/67/2022                1  none   C1
# 589  plate4_5J8_none-3_1   A/Wisconsin/67/2022                1  none   C1
# 590  plate4_5J8_none-3_1   A/Wisconsin/67/2022                1  none   C1
#
#               barcode  count               sample_well  counts_perwell  \
# 0    ATATCAAGACTAGATG   9401  plate4_5J8_none-1_1 (A1)         1196049
# 1    CCGTTCTAAAACGCTA   3322  plate4_5J8_none-1_1 (A1)         1196049
# 2    CGGCAGGATATTGCAG  10082  plate4_5J8_none-1_1 (A1)         1196049
# 3    ACAAATAGTTTATAGA   7697  plate4_5J8_none-1_1 (A1)         1196049
# 4    CCACATAGGCGTTTTT    347  plate4_5J8_none-1_1 (A1)         1196049
# ..                ...    ...                       ...             ...
# 586  GAAGAAACTATAACCA  17669  plate4_5J8_none-3_1 (C1)          986264
# 587  TATATTAGTAACATAA   3787  plate4_5J8_none-3_1 (C1)          986264
# 588  AAAGCTCTTTTCGTTC  12576  plate4_5J8_none-3_1 (C1)          986264
# 589  AGGAAAGAAACTGGAG   3103  plate4_5J8_none-3_1 (C1)          986264
# 590  CTGAACTTGTCGATAT   1798  plate4_5J8_none-3_1 (C1)          986264
#
#      fraction_barcode  fraction_strain_perwell  \
# 0            0.007860                 0.019067
# 1            0.002777                 0.019067
# 2            0.008429                 0.019067
# 3            0.006435                 0.012108
# 4            0.000290                 0.012108
# ..                ...                      ...
# 586          0.017915                 0.023242
# 587          0.003840                 0.023242
# 588          0.012751                 0.017720
# 589          0.003146                 0.017720
# 590          0.001823                 0.017720
#
#      mean_fraction_strains_subsetwells  ratio_to_add  mean_ratio_to_add
# 0                             0.020088      0.782788           0.743006
# 1                             0.020088      0.782788           0.743006
# 2                             0.020088      0.782788           0.743006
# 3                             0.012144      1.232667           1.228996
# 4                             0.012144      1.232667           1.228996
# ..                                 ...           ...                ...
# 586                           0.023930      0.642165           0.623702
# 587                           0.023930      0.642165           0.623702
# 588                           0.018456      0.842270           0.808699
# 589                           0.018456      0.842270           0.808699
# 590                           0.018456      0.842270           0.808699
#
# [591 rows x 14 columns]

# %%
tidy = mean_single_well[['strain', 'mean_fraction_strains_subsetwells', 'mean_ratio_to_add']].drop_duplicates()
(mean_single_well
                 [['strain', 'mean_fraction_strains_subsetwells']]
                 .drop_duplicates()
                 .plot.barh(x="strain", y="mean_fraction_strains_subsetwells", figsize = (6,14), log=False)
)
# Out:
# <Axes: ylabel='strain'>

# %%
tidy['vol_to_add'] = tidy['mean_ratio_to_add'].apply(lambda x: x * 70).to_list()

# %%
tidy
# Out:
#                                   strain  mean_fraction_strains_subsetwells  \
# 0                   A/Argentina/677/2023                           0.020088
# 3                   A/Argentina/824/2023                           0.012144
# 6                      A/Arizona/43/2023                           0.010460
# 9             A/Arizona/IVYG43Q65T3/2023                           0.018248
# 12   A/Brazil/GIHSN-HCL023128467501/2023                           0.029628
# ..                                   ...                                ...
# 182                 A/Victoria/2241/2023                           0.014926
# 185          A/Victoria/4897/2022_IVR238                           0.006224
# 188                 A/Washington/32/2023                           0.019332
# 191                 A/Wisconsin/588/2019                           0.023930
# 194                  A/Wisconsin/67/2022                           0.018456
#
#      mean_ratio_to_add  vol_to_add
# 0             0.743006   52.010408
# 3             1.228996   86.029717
# 6             1.426867   99.880703
# 9             0.817898   57.252868
# 12            0.503762   35.263342
# ..                 ...         ...
# 182           0.999983   69.998827
# 185           2.398000  167.860000
# 188           0.772062   54.044319
# 191           0.623702   43.659168
# 194           0.808699   56.608951
#
# [66 rows x 4 columns]

# %%
tidy = mean_single_well[['strain', 'mean_fraction_strains_subsetwells', 'mean_ratio_to_add']].drop_duplicates()
tidy.plot.barh(x="strain", y="mean_ratio_to_add", figsize = (6,14))
# Out:
# <Axes: ylabel='strain'>

# %%
strains_to_add = ['A/Oregon/Flu-OHSU-241140095/2023','A/Victoria/4897/2022_IVR238']

# %%
tidy['strainstoadd'] = np.where(tidy['strain'].isin(strains_to_add),"yes","no")

# %%
tidy_strainspooled = tidy.loc[tidy['strainstoadd'] == "no"]

# %%
tidy_strainstoadd = tidy.loc[tidy['strainstoadd'] == "yes"]

# %%
tidy.to_csv("../results/miscellaneous_plates/test_volumestoadd.csv")
